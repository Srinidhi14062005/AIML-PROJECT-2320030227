# %% [markdown]
# <a href="https://colab.research.google.com/github/Srinidhi14062005/AIML-PROJECT-2320030227/blob/main/Linear%2CLogistic_Regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#linear regression


def linear_regression(x, y):

    if len(x) != len(y):
        raise ValueError("x and y must have the same number of elements.")

    n = len(x)


    sum_x = sum(x)
    sum_y = sum(y)
    sum_xy = sum(xi * yi for xi, yi in zip(x, y))
    sum_x2 = sum(xi ** 2 for xi in x)


    m = (n * sum_xy - sum_x * sum_y) / (n * sum_x2 - sum_x ** 2)
    b = (sum_y - m * sum_x) / n


    return m, b


x = [1, 2, 3, 4, 5]
y = [2, 4, 5, 4, 5]

m, b = linear_regression(x, y)

print(f"Slope (m): {m}")
print(f"Intercept (b): {b}")


def predict(x_val, m, b):
    return m * x_val + b


x_val = 6
predicted_y = predict(x_val, m, b)
print(f"Predicted value for x = {x_val}: {predicted_y}")
# Out:
# Slope (m): 0.6
# Intercept (b): 2.2
# Predicted value for x = 6: 5.8

# %%
# Import necessary libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression, LogisticRegression
from sklearn.metrics import mean_squared_error, accuracy_score, confusion_matrix

# Example dataset generation for demonstration
def generate_data():
    # For Linear Regression
    np.random.seed(42)
    X_linear = 2 * np.random.rand(100, 1)
    y_linear = 4 + 3 * X_linear + np.random.randn(100, 1)

    # For Logistic Regression
    X_logistic = np.random.randn(100, 2)
    y_logistic = (X_logistic[:, 0] + X_logistic[:, 1] > 0).astype(int)

    return X_linear, y_linear, X_logistic, y_logistic

# Split the data
X_linear, y_linear, X_logistic, y_logistic = generate_data()

# Train-test split
X_train_linear, X_test_linear, y_train_linear, y_test_linear = train_test_split(X_linear, y_linear, test_size=0.2, random_state=42)
X_train_logistic, X_test_logistic, y_train_logistic, y_test_logistic = train_test_split(X_logistic, y_logistic, test_size=0.2, random_state=42)

# --- Linear Regression Implementation ---
print("Linear Regression")
linear_model = LinearRegression()
linear_model.fit(X_train_linear, y_train_linear)

# Predictions for Linear Regression
y_pred_linear = linear_model.predict(X_test_linear)

# Model evaluation
mse = mean_squared_error(y_test_linear, y_pred_linear)
print(f"Mean Squared Error: {mse:.2f}")

# Plotting the Linear Regression result
plt.scatter(X_test_linear, y_test_linear, color='blue', label='Actual')
plt.plot(X_test_linear, y_pred_linear, color='red', label='Predicted')
plt.title("Linear Regression")
plt.xlabel("X")
plt.ylabel("y")
plt.legend()
plt.show()

# --- Logistic Regression Implementation ---
print("\nLogistic Regression")
logistic_model = LogisticRegression()
logistic_model.fit(X_train_logistic, y_train_logistic)

# Predictions for Logistic Regression
y_pred_logistic = logistic_model.predict(X_test_logistic)

# Model evaluation
accuracy = accuracy_score(y_test_logistic, y_pred_logistic)
print(f"Accuracy: {accuracy:.2f}")

# Confusion matrix for Logistic Regression
conf_matrix = confusion_matrix(y_test_logistic, y_pred_logistic)
print("Confusion Matrix:")
print(conf_matrix)
# Out:
# Linear Regression
# Mean Squared Error: 0.65
# Logistic Regression
# Accuracy: 1.00
# Confusion Matrix:
# [[ 8  0]
#  [ 0 12]]
